# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import requests
import time
import pandas as pd
import regex as re
import numpy as np
import string

# %%
#go to webpage
URL = "https://www.asos.com/search/?page=1&q=adidas%20mens%20short%20sleeve"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(50)
subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")

# %%
count=0
for i in soup.find_all(class_="bOpxk49"): #price
    count+=1
print(count)
# Out:
# 72

# %%
count1=0
for i in soup.find_all(class_="ERlP6Bx"): #price
    count1+=1
    print(i.img['src'])
print(count1)
# Out:
# //images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-training-ombre-t-shirt-in-blue/20508579-1-blue?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-originals-windbreaker-jacket-with-3d-trefoil-in-black/20192215-1-black?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-training-aero-t-shirt-in-blue/14131797-1-blue?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-training-t-shirt-with-high-chest-logo-in-grey/22291433-1-grey?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-originals-essentials-t-shirt-in-pink/14658082-1-pink?$n_480w$&wid=476&fit=constrain
# //images.asos-media.com/products/adidas-training-logo-t-shirt-in-lime/14131810-1-lime?$n_480w$&wid=476&fit=constrain
# ...

# %%
print(count1)
# Out:
# 49

# %%
soup
# Out:
# <html data-country-code="GB" data-platform="desktop" data-store-code="COM" lang="en-GB"><head class="at-element-marker"><meta charset="utf-8"/><title>Search: adidas mens short sleeve - page 1 of 3 | ASOS</title><meta content="Search for adidas mens short sleeve at ASOS. Shop from over 70,000 styles, including adidas mens short sleeve. Discover the latest women’s and men’s fashion online" name="description"/><meta content="7d543da16a86f7ad75c452097bfa9e47" name="p:domain_verify"/><meta content="0BC251BA275FCFB5D0505FEBC89F03B6" name="msvalidate.01"/><meta content="123073601043263" property="fb:app_id"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="NOODP" name="Slurp"/><meta content="NOYDIR" name="Slurp"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/manifest.
# ...

# %%
img1=soup.find_all(class_="ERlP6Bx")
img1[8]
# Out:
# <div class="ERlP6Bx"><img alt="adidas 8-Bit graphic foil t-shirt in black" class="_1Jj-2sd" data-auto-id="productTileEmptyImage"/></div>

# %%
#wait = WebDriverWait(driver,20)

for i in range(count):
    print(soup.find_all(class_="_3J74XsK")[i].text) #title
    print(soup.find_all(class_="bOpxk49")[i].text) #new price
    print(soup.find_all(class_='_2qG85dG')[i].a['href']) #details
    print(soup.find_all(class_="ERlP6Bx")[i].img['src']) #img
    print(i)
# Out:
# adidas Training t-shirt in black
# £19.55
# https://www.asos.com/adidas-performance/adidas-training-t-shirt-in-black/prd/14661131?colourwayid=16634350&SearchQuery=adidas%20mens%20short%20sleeve
# //images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&wid=476&fit=constrain
# 0
# adidas Training ombre t-shirt in blue
# £23.10
# https://www.asos.com/adidas-performance/adidas-training-ombre-t-shirt-in-blue/prd/20508579?colourwayid=60059707&SearchQuery=adidas%20mens%20short%20sleeve
# //images.asos-media.com/products/adidas-training-ombre-t-shirt-in-blue/20508579-1-blue?$n_480w$&wid=476&fit=constrain
# 1
# adidas Originals windbreaker jacket with 3D trefoil in black
# £32.45
# https://www.asos.com/adidas-originals/adidas-originals-windbreaker-jacket-with-3d-trefoil-in-black/prd/20192215?colourwayid=60016222&SearchQuery=adidas%20mens%20short%20sleeve
# ...

# %%
i=0
while i<count:
    try:
        print(i)
        print(soup.find_all(class_="_3J74XsK")[i].text) #title
        print(soup.find_all(class_="bOpxk49")[i].text) #new price
        print(soup.find_all(class_='_2qG85dG')[i].a['href']) #details
        print(soup.find_all(class_="ERlP6Bx")[i].img['src']) #img
        i+=1
    except:
        print('skip')

# %%
for i in soup.find_all(class_="ERlP6Bx"):#img
    print(i)

# %%
#image
for i in soup.find_all(class_="ERlP6Bx"):
    #print(i.img['alt']) #title
    print('https:'+i.img['src']) #img
# Out:
# https://images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-training-ombre-t-shirt-in-blue/20508579-1-blue?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-originals-windbreaker-jacket-with-3d-trefoil-in-black/20192215-1-black?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-training-aero-t-shirt-in-blue/14131797-1-blue?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-training-t-shirt-with-high-chest-logo-in-grey/22291433-1-grey?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-originals-essentials-t-shirt-in-pink/14658082-1-pink?$n_480w$&wid=476&fit=constrain
# https://images.asos-media.com/products/adidas-training-logo-t-shirt-in-lime/14131810-1-lime?$n_480w$&wid=476&fit=constrain
# ...

# %%
for i in soup.find_all(class_="ERlP6Bx"):
    print(i)
# Out:
# <div class="ERlP6Bx"><img alt="adidas Training t-shirt in black" class="_2r9Zh0W" data-auto-id="productTileImage" sizes="(min-width: 768px) 317px, 238px" src="//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&amp;wid=476&amp;fit=constrain" srcset="//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_240w$&amp;wid=238&amp;fit=constrain 238w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_320w$&amp;wid=317&amp;fit=constrain 317w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&amp;wid=476&amp;fit=constrain 476w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_640w$&amp;wid=634&amp;fit=constrain 634w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_750w$&amp;wid=714&amp;fit=constrain 714w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/1466113
# ...

# %%
for i in soup.find("article"):
    print(i.find('div',attrs={'data-auto-id':'productTileDescription'})) #find all the "div ", which attributes ={"element":"vlaue"}
    print(i.find('span',attrs={'data-auto-id':'productTileSaleAmount'}))
    #print(i.find())

# %%
for i in soup.find(class_='_2qG85dG'):
    print(i.text)
    print(i.find('img')['src'])
    #i.find('a')['href']
# Out:
# adidas Training t-shirt in black£27.95 £19.55
# //images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&wid=476&fit=constrain
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-c52becd7781e> in <module>
#       1 for i in soup.find(class_='_2qG85dG'):
#       2     print(i.text)
# ----> 3     print(i.find('img')['src'])
#       4     #i.find('a')['href']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
for i in range(count):
    print(soup.find_all(class_="_3J74XsK")[i].text) #title
    print(soup.find_all(class_="bOpxk49")[i].text) #new price
    print(soup.find_all(class_='_2qG85dG')[i].a['href']) #details
    print(soup.find_all(class_="ERlP6Bx")[i].img['src']) #img
    print(i)

# %%
#article class
for i in soup.find(class_='_2qG85dG'):
# Out:
# <article class="_2qG85dG" data-auto-id="productTile" id="product-14661131"><a aria-label="adidas Training t-shirt in black, current price: £19.55, Original price: £27.95" class="_3TqU78D" href="https://www.asos.com/adidas-performance/adidas-training-t-shirt-in-black/prd/14661131?colourwayid=16634350&amp;SearchQuery=adidas%20mens%20short%20sleeve"><div class="ERlP6Bx"><img alt="adidas Training t-shirt in black" class="_2r9Zh0W" data-auto-id="productTileImage" sizes="(min-width: 768px) 317px, 238px" src="//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&amp;wid=476&amp;fit=constrain" srcset="//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_240w$&amp;wid=238&amp;fit=constrain 238w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_320w$&amp;wid=317&amp;fit=constrain 317w,//images.asos-media.com/products/adidas-training-t-shirt-in-black/14661131-1-black?$n_480w$&amp;wid=476&a
# ...

# %%
#'load more' link ---- next page
soup.find(class_='_39_qNys')['href']
# Out:
# 'https://www.asos.com/search/?page=2&q=adidas%20mens%20short%20sleeve'

# %%
soup.find_all('article')
# Out:
# []

# %%
#go to webpage
URL = "https://www.asos.com/search/?page=1&q=adidas%20mens%20short%20sleeve"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(15)

# Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 35):
    driver.execute_script("window.scrollTo(0, {});".format(i))
    time.sleep(0.05)

subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_shortsleeve = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image ='http:' + i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            
            
            
        count+=1
        print(count)
        


        df_men_shortsleeve = df_men_shortsleeve.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
    time.sleep(5)
    
    # #going to the next page, ie. 'load more'
    counter +=1
    temp = 'https://www.asos.com/search/?page='
    temp2 = '&q=adidas%20mens%20short%20sleeve'
    #https://www.asos.com/search/?page=3&q=adidas%20mens%20short%20sleeve
    URL = temp + str(counter) + temp2
    driver.get(URL) 
    
    # Smooth Scorlling
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 35):
        driver.execute_script("window.scrollTo(0, {});".format(i))
        time.sleep(0.05)
    
    subhtml = driver.page_source
    soup = BeautifulSoup(subhtml, "html.parser")
    

    
#     # product image
#     try:
#         product_image = i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
#         print('http:' + product_image)
#     except:
#         product_image = np.nan

    if counter==5:
        break

    #break
# Out:
# adidas Training t-shirt with high chest logo in grey
# https://www.asos.com/adidas-performance/adidas-training-t-shirt-with-high-chest-logo-in-grey/prd/22291433?colourwayid=60387456&SearchQuery=adidas%20mens%20short%20sleeve
# http://images.asos-media.com/products/adidas-training-t-shirt-with-high-chest-logo-in-grey/22291433-1-grey?$n_480w$&wid=476&fit=constrain
# 1
# adidas Training 3 stripe t-shirt in pink
# https://www.asos.com/adidas-performance/adidas-training-3-stripe-t-shirt-in-pink/prd/14661134?colourwayid=16634343&SearchQuery=adidas%20mens%20short%20sleeve
# http://images.asos-media.com/products/adidas-training-3-stripe-t-shirt-in-pink/14661134-1-pink?$n_480w$&wid=476&fit=constrain
# 2
# adidas Training Aero t-shirt in blue
# https://www.asos.com/adidas-performance/adidas-training-aero-t-shirt-in-blue/prd/14131797?colourwayid=16593816&SearchQuery=adidas%20mens%20short%20sleeve
# ...

# %%
df_men_shortsleeve
# Out:
#                                          product_image product_price  \
# 0    http://images.asos-media.com/products/adidas-t...        £34.95
# 1    http://images.asos-media.com/products/adidas-t...        £28.00
# 2    http://images.asos-media.com/products/adidas-t...        £27.95
# 3    http://images.asos-media.com/products/adidas-t...        £22.00
# 4    http://images.asos-media.com/products/adidas-8...        £16.00
# ..                                                 ...           ...
# 215  http://images.asos-media.com/products/adidas-t...        £15.60
# 216  http://images.asos-media.com/products/adidas-o...        £16.80
# 217  http://images.asos-media.com/products/adidas-z...        £13.50
# 218  http://images.asos-media.com/products/adidas-t...         £8.00
# 219  http://images.asos-media.com/products/adidas-o...        £19.20
#
#                                          product_title  \
# 0    adidas Training t-shirt with high chest logo i...
# ...

# %%
df_men_shortsleeve.to_csv('men_shortsleeve.csv')

# %%
df_men_shortsleeve
# Out:
#                                          product_image product_price  \
# 0    //images.asos-media.com/products/adidas-traini...        £19.55
# 1    //images.asos-media.com/products/adidas-traini...        £19.55
# 2    //images.asos-media.com/products/adidas-origin...        £32.45
# 3    //images.asos-media.com/products/adidas-traini...        £15.40
# 4    //images.asos-media.com/products/adidas-traini...        £24.45
# ..                                                 ...           ...
# 208                                                NaN        £16.95
# 209                                                NaN        £19.60
# 210                                                NaN        £17.95
# 211                                                NaN        £22.35
# 212                                                NaN        £21.20
#
#                                          product_title  \
# 0                     adidas Training t-shirt in black
# ...

# %%
#go to webpage
URL = "https://www.asos.com/search/?currentpricerange=5-145&q=adidas%20mens&refine=attribute_1047:8405"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(20)
subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_longsleeve_s = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image = 'http:'+i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            


        count+=1
        print(count)

        df_men_longsleeve_s = df_men_longsleeve_s.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
#     time.sleep(5)
    
#     # #going to the next page, ie. 'load more'
#     counter +=1
#     temp = 'https://www.asos.com/search/?page='
#     temp2 = '&q=adidas%20mens%20short%20sleeve'
#     URL = temp + str(counter) + temp2
#     driver.get(URL) 
#     subhtml = driver.page_source
#     soup = BeautifulSoup(subhtml, "html.parser")
    
    

#     if counter==1:
#         break

    break
# Out:
# adidas box logo sweatshirt in black
# £31.45
# https://www.asos.com/adidas-performance/adidas-box-logo-sweatshirt-in-black/prd/20773198?colourwayid=60086795&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-box-logo-sweatshirt-in-black/20773198-1-black?$n_480w$&wid=476&fit=constrain
# 1
# adidas Areoready zip thru hoodie with logo in black
# £41.95
# https://www.asos.com/adidas-performance/adidas-areoready-zip-thru-hoodie-with-logo-in-black/prd/22281457?colourwayid=60386881&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-areoready-zip-thru-hoodie-with-logo-in-black/22281457-1-black?$n_480w$&wid=476&fit=constrain
# 2
# adidas Originals collegiate crest co-ord in black
# From £94.40
# https://www.asos.com/adidas-originals/adidas-originals-collegiate-crest-co-ord-in-black/grp/31016?colourwayid=60095319&SearchQuery=adidas%20mens
# ...

# %%
#old
df_men_longsleeve
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-o...        £30.05
# 1   http://images.asos-media.com/products/adidas-o...        £25.75
# 2   http://images.asos-media.com/products/adidas-o...        £20.95
# 3   http://images.asos-media.com/products/adidas-o...        £25.45
# 4   http://images.asos-media.com/products/adidas-o...        £29.65
# 5   http://images.asos-media.com/products/adidas-t...        £23.10
# 6   http://images.asos-media.com/products/adidas-o...        £29.65
# 7   http://images.asos-media.com/products/adidas-t...        £29.70
# 8   http://images.asos-media.com/products/adidas-o...        £29.70
# 9   http://images.asos-media.com/products/adidas-o...        £19.75
# 10  http://images.asos-media.com/products/adidas-o...        £32.25
# 11  http://images.asos-media.com/products/adidas-o...        £31.45
# 12  http://images.asos-media.com/products/adidas-o...        £23.05
# ...

# %%
#new
df_men_longsleeve
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-b...        £31.45
# 1   http://images.asos-media.com/products/adidas-a...        £41.95
# 2   http://images.asos-media.com/groups/adidas-ori...   From £94.40
# 3   http://images.asos-media.com/products/adidas-o...        £49.45
# 4   http://images.asos-media.com/products/adidas-s...        £35.00
# 5   http://images.asos-media.com/products/adidas-t...        £38.50
# 6   http://images.asos-media.com/products/adidas-o...        £38.65
# 7   http://images.asos-media.com/products/adidas-o...        £38.65
# 8   http://images.asos-media.com/products/adidas-o...        £38.65
# 9   http://images.asos-media.com/products/adidas-o...        £38.65
# 10  http://images.asos-media.com/products/adidas-o...        £34.15
# 11  http://images.asos-media.com/groups/adidas-ori...   From £94.40
# 12  http://images.asos-media.com/products/adidas-o...        £49.45
# ...

# %%
df_men_longsleeve.to_csv('men_longsleeve_s.csv')

# %%
#go to webpage
URL = "https://www.asos.com/search/?q=adidas+mens+polo"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(20)
subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_polo = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = np.nan

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image = 'http:'+i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            


        count+=1
        print(count)

        df_men_polo = df_men_polo.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
#     time.sleep(5)
    
#     # #going to the next page, ie. 'load more'
#     counter +=1
#     temp = 'https://www.asos.com/search/?page='
#     temp2 = '&q=adidas%20mens%20short%20sleeve'
#     URL = temp + str(counter) + temp2
#     driver.get(URL) 
#     subhtml = driver.page_source
#     soup = BeautifulSoup(subhtml, "html.parser")
    
    

#     if counter==1:
#         break

    break
# Out:
# adidas Originals long sleeve polo top with collegiate crest in terry towelling
# £44.95
# https://www.asos.com/adidas-originals/adidas-originals-long-sleeve-polo-top-with-collegiate-crest-in-terry-towelling/prd/20863594?colourwayid=60095314&SearchQuery=adidas%20mens%20polo
# http://images.asos-media.com/products/adidas-originals-long-sleeve-polo-top-with-collegiate-crest-in-terry-towelling/20863594-1-navy?$n_480w$&wid=476&fit=constrain
# 1
# adidas Originals long sleeve polo top with collegiate crest in burgundy terry toweling
# £44.95
# https://www.asos.com/adidas-originals/adidas-originals-long-sleeve-polo-top-with-collegiate-crest-in-burgundy-terry-toweling/prd/20863588?colourwayid=60095341&SearchQuery=adidas%20mens%20polo
# http://images.asos-media.com/products/adidas-originals-long-sleeve-polo-top-with-collegiate-crest-in-burgundy-terry-toweling/20863588-1-burgundy?$n_480w$&wid=476&fit=constrain
# 2
# adidas Golf three stripe polo in white
# £29.75
# ...

# %%
df_men_polo
# Out:
#                                        product_image product_price  \
# 0  http://images.asos-media.com/products/adidas-o...        £44.95
# 1  http://images.asos-media.com/products/adidas-o...        £44.95
# 2  http://images.asos-media.com/products/adidas-g...        £29.75
# 3  http://images.asos-media.com/products/adidas-g...        £26.25
# 4  http://images.asos-media.com/products/adidas-g...        £26.25
# 5  http://images.asos-media.com/products/adidas-o...        £22.00
# 6  http://images.asos-media.com/products/adidas-o...        £28.50
# 7  http://images.asos-media.com/products/adidas-o...        £19.80
#
#                                        product_title  \
# 0  adidas Originals long sleeve polo top with col...
# 1  adidas Originals long sleeve polo top with col...
# 2             adidas Golf three stripe polo in white
# 3             adidas Golf three stripe polo in black
# 4              adidas Golf three stripe polo in grey
# ...

# %%
df_men_polo.to_csv('men_longsleeve2.csv')

# %%
soup.find(class_='_16nzq18').text
# Out:
# '£42.95'

# %%
#go to webpage
URL = "https://www.asos.com/search/?currentpricerange=5-145&q=adidas%20mens&refine=attribute_1047:8391"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(15)

# Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 35):
    driver.execute_script("window.scrollTo(0, {});".format(i))
    time.sleep(0.05)
    
    
subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_hoodie = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image = 'http:'+i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            


        count+=1
        print(count)

        df_men_hoodie = df_men_hoodie.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
#     time.sleep(5)
    
#     # #going to the next page, ie. 'load more'
#     counter +=1
#     temp = 'https://www.asos.com/search/?page='
#     temp2 = '&q=adidas%20mens%20short%20sleeve'
#     URL = temp + str(counter) + temp2
#     driver.get(URL) 
#     subhtml = driver.page_source
#     soup = BeautifulSoup(subhtml, "html.parser")
    
    

#     if counter==1:
#         break

    break
# Out:
# adidas Originals essentials hoodie in white
# https://www.asos.com/adidas-originals/adidas-originals-essentials-hoodie-in-white/prd/21139545?colourwayid=60143323&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-originals-essentials-hoodie-in-white/21139545-1-white?$n_480w$&wid=476&fit=constrain
# 1
# adidas Originals outline hoodie in grey
# £38.46
# https://www.asos.com/adidas-originals/adidas-originals-outline-hoodie-in-grey/prd/22686851?colourwayid=60417311&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-originals-outline-hoodie-in-grey/22686851-1-grey?$n_480w$&wid=476&fit=constrain
# 2
# adidas Originals monogram hoodie in black
# https://www.asos.com/adidas-originals/adidas-originals-monogram-hoodie-in-black/prd/22350203?colourwayid=60391872&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-originals-monogram-hoodie-in-black/22350203-1-black?$n_480w$&wid=476&fit=constrain
# 3
# ...

# %%
df_men_hoodie
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-o...        £42.95
# 1   http://images.asos-media.com/products/adidas-o...        £38.46
# 2   http://images.asos-media.com/products/adidas-o...        £62.95
# 3   http://images.asos-media.com/products/adidas-o...        £59.95
# 4   http://images.asos-media.com/groups/adidas-ori...       £109.90
# 5   http://images.asos-media.com/products/adidas-o...        £59.95
# 6   http://images.asos-media.com/products/adidas-t...        £50.00
# 7   http://images.asos-media.com/products/adidas-o...        £74.95
# 8   http://images.asos-media.com/products/adidas-o...        £49.95
# 9   http://images.asos-media.com/products/adidas-o...        £62.95
# 10  http://images.asos-media.com/products/adidas-o...        £49.95
# 11  http://images.asos-media.com/products/adidas-t...        £45.00
# 12  http://images.asos-media.com/products/adidas-o...        £62.95
# ...

# %%
df_men_hoodie.to_csv('men_hoodie.csv')

# %%
#go to webpage
URL = "https://www.asos.com/search/?currentpricerange=5-160&q=adidas%20mens&refine=attribute_1047:8406,10885,8401"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(15)

# Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 35):
    driver.execute_script("window.scrollTo(0, {});".format(i))
    time.sleep(0.05)
    
    
subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_jacket = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image = 'http:'+i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            


        count+=1
        print(count)

        df_men_jacket = df_men_jacket.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
#     time.sleep(5)
    
#     # #going to the next page, ie. 'load more'
#     counter +=1
#     temp = 'https://www.asos.com/search/?page='
#     temp2 = '&q=adidas%20mens%20short%20sleeve'
#     URL = temp + str(counter) + temp2
#     driver.get(URL) 
#     subhtml = driver.page_source
#     soup = BeautifulSoup(subhtml, "html.parser")
    
    

#     if counter==1:
#         break

    break
# Out:
# adidas Outdoors bomber jacket in black
# https://www.asos.com/adidas-performance/adidas-outdoors-bomber-jacket-in-black/prd/22281169?colourwayid=60386860&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-outdoors-bomber-jacket-in-black/22281169-1-black?$n_480w$&wid=476&fit=constrain
# 1
# adidas Originals large logo print jacket in blue
# £48.96
# https://www.asos.com/adidas-originals/adidas-originals-large-logo-print-jacket-in-blue/prd/22686838?colourwayid=60417305&SearchQuery=adidas%20mens
# http://images.asos-media.com/products/adidas-originals-large-logo-print-jacket-in-blue/22686838-1-blue?$n_480w$&wid=476&fit=constrain
# 2
# adidas Originals large logo print jacket in orange
# £48.96
# https://www.asos.com/adidas-originals/adidas-originals-large-logo-print-jacket-in-orange/prd/22687236?colourwayid=60417341&SearchQuery=adidas%20mens
# ...

# %%
df_men_jacket
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-o...        £74.95
# 1   http://images.asos-media.com/products/adidas-o...        £48.96
# 2   http://images.asos-media.com/products/adidas-o...        £48.96
# 3   http://images.asos-media.com/products/adidas-v...        £48.96
# 4   http://images.asos-media.com/products/adidas-o...        £74.95
# ..                                                ...           ...
# 65  http://images.asos-media.com/products/adidas-o...        £44.00
# 66  http://images.asos-media.com/products/adidas-o...        £45.00
# 67  http://images.asos-media.com/products/adidas-3...        £40.00
# 68  http://images.asos-media.com/products/adidas-o...        £44.05
# 69  http://images.asos-media.com/products/adidas-t...        £50.00
#
#                                         product_title  \
# 0              adidas Outdoors bomber jacket in black
# ...

# %%
df_men_jacket.to_csv('men_jacket.csv')

# %%
#go to webpage
URL = "https://www.asos.com/search/?currentpricerange=10-110&page=1&q=adidas%20men%20shorts&refine=attribute_1047%3A8386%2C8576"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(15)

# Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 35):
    driver.execute_script("window.scrollTo(0, {});".format(i))
    time.sleep(0.05)

subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_shorts = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image ='http:' + i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            
            
            
        count+=1
        print(count)
        


        df_men_shorts = df_men_shorts.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
    time.sleep(5)
    
    # #going to the next page, ie. 'load more'
    counter +=1
    temp = 'https://www.asos.com/search/?currentpricerange=10-110&page='
    temp2 = '&q=adidas%20men%20shorts&refine=attribute_1047%3A8386%2C8576'
    #https://www.asos.com/search/?page=3&q=adidas%20mens%20short%20sleeve
    URL = temp + str(counter) + temp2
    driver.get(URL) 
    
    # Smooth Scorlling
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 35):
        driver.execute_script("window.scrollTo(0, {});".format(i))
        time.sleep(0.05)
    
    subhtml = driver.page_source
    soup = BeautifulSoup(subhtml, "html.parser")
    

    
#     # product image
#     try:
#         product_image = i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
#         print('http:' + product_image)
#     except:
#         product_image = np.nan

    if counter==3:
        break

    #break
# Out:
# adidas Training shorts in black with contrast panels
# https://www.asos.com/adidas-performance/adidas-training-shorts-in-black-with-contrast-panels/prd/22281171?colourwayid=60386859&SearchQuery=adidas%20men%20shorts
# http://images.asos-media.com/products/adidas-training-shorts-in-black-with-contrast-panels/22281171-1-black?$n_480w$&wid=476&fit=constrain
# 1
# adidas Training shorts in black
# https://www.asos.com/adidas-performance/adidas-training-shorts-in-black/prd/21106913?colourwayid=60140927&SearchQuery=adidas%20men%20shorts
# http://images.asos-media.com/products/adidas-training-shorts-in-black/21106913-1-black?$n_480w$&wid=476&fit=constrain
# 2
# adidas Training shorts in black
# https://www.asos.com/adidas-performance/adidas-training-shorts-in-black/prd/14661145?colourwayid=16634356&SearchQuery=adidas%20men%20shorts
# http://images.asos-media.com/products/adidas-training-shorts-in-black/14661145-1-black?$n_480w$&wid=476&fit=constrain
# 3
# adidas 3 stripes shorts blue
# ...

# %%
df_men_shorts
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-t...        £34.95
# 1   http://images.asos-media.com/products/adidas-t...        £29.95
# 2   http://images.asos-media.com/products/adidas-t...        £38.00
# 3   http://images.asos-media.com/products/adidas-3...        £34.95
# 4   http://images.asos-media.com/products/adidas-t...        £33.00
# ..                                                ...           ...
# 80  http://images.asos-media.com/products/adidas-s...        £18.90
# 81  http://images.asos-media.com/products/adidas-t...        £23.05
# 82  http://images.asos-media.com/products/adidas-s...        £12.00
# 83  http://images.asos-media.com/groups/adidas-ori...   From £50.85
# 84  http://images.asos-media.com/products/adidas-o...        £18.20
#
#                                         product_title  \
# 0   adidas Training shorts in black with contrast ...
# ...

# %%
df_men_shorts.to_csv('men_shorts.csv')

# %%
#go to webpage
URL = "https://www.asos.com/search/?currentpricerange=5-170&page=1&q=adidas%20men&refine=attribute_1047:8407,8397"
driver = webdriver.Chrome(executable_path='/Applications/chromedriver 2')
wait = WebDriverWait(driver,100)
driver.get(URL)
time.sleep(5)
driver.find_element_by_xpath('/html/body/div[4]/div/div/button/span').click()
wait = WebDriverWait(driver,100)
time.sleep(15)

# Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 35):
    driver.execute_script("window.scrollTo(0, {});".format(i))
    time.sleep(0.05)

subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df_men_pants = pd.DataFrame()

count=0
counter = 1
while True:
    
    for i in soup.find_all('article'):

         # extract product title
        try:
            product_title=i.find(class_="_3J74XsK").text #title
            print(product_title)
        except:
            product_title = np.nan

        # extract product price
        try:
            product_price = i.find(class_="bOpxk49").text
            print(product_price)
        except:
            product_price = i.find(class_="_16nzq18").text

        # product url
        try:
            product_url = i.find('a')['href']
            print(product_url)
        except:
            product_url = np.nan
        
        # product image
        try:
            product_image ='http:' + i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
            print(product_image)
        except:
            product_image = np.nan
            
            
            
        count+=1
        print(count)
        


        df_men_pants = df_men_pants.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)
        
    time.sleep(5)
    
    # #going to the next page, ie. 'load more'
    counter +=1
    temp = 'https://www.asos.com/search/?currentpricerange=5-170&page='
    temp2 = '&q=adidas%20men&refine=attribute_1047:8407,8397'
    #https://www.asos.com/search/?page=3&q=adidas%20mens%20short%20sleeve
    URL = temp + str(counter) + temp2
    driver.get(URL) 
    
    # Smooth Scorlling
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 35):
        driver.execute_script("window.scrollTo(0, {});".format(i))
        time.sleep(0.05)
    
    subhtml = driver.page_source
    soup = BeautifulSoup(subhtml, "html.parser")
    

    
#     # product image
#     try:
#         product_image = i.find(class_='ERlP6Bx').img['src']   #class_="ERlP6Bx")[i].img['src']
#         print('http:' + product_image)
#     except:
#         product_image = np.nan

    if counter==3:
        break

    #break
# Out:
# adidas Originals outline trefoil track joggers in blue
# https://www.asos.com/adidas-originals/adidas-originals-outline-trefoil-track-joggers-in-blue/prd/22355342?colourwayid=60392357&SearchQuery=adidas%20men
# http://images.asos-media.com/products/adidas-originals-outline-trefoil-track-joggers-in-blue/22355342-1-blue?$n_480w$&wid=476&fit=constrain
# 1
# adidas Originals essentials joggers in black
# https://www.asos.com/adidas-originals/adidas-originals-essentials-joggers-in-black/prd/21836992?colourwayid=60303329&SearchQuery=adidas%20men
# http://images.asos-media.com/products/adidas-originals-essentials-joggers-in-black/21836992-1-black?$n_480w$&wid=476&fit=constrain
# 2
# adidas Originals Firebird joggers in black with 3-stripes
# https://www.asos.com/adidas-originals/adidas-originals-firebird-joggers-in-black-with-3-stripes/prd/21139555?colourwayid=60143308&SearchQuery=adidas%20men
# ...

# %%
df_men_pants.to_csv('men_shorts.csv')

# %%
#jeff

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
import pandas as pd
import regex as re
import numpy as np
import requests
import string
import time 

domain = 'https://www.adidas.com.hk'
URL = 'https://www.adidas.com.hk/search?ci=1003&pf=18-49%2C18-158%2C2-1222%2C2-1222&cf=1-3%2C1-3&pr=-&fo=p18%2Cp18%2Cc1%2Cp2%2Cc1%2Cp2&pn=1&pageSize=120&c=Clothing-Clothing&p=undefined-MEN%26undefined-UNISEX%26PRODUCT++TYPE-T-Shirts+(Short+Sleeve)%26PRODUCT++TYPE-T-Shirts+(Short+Sleeve)&isSaleTop=false&isNew=false&ps=1&locale=en_GB'
driver = webdriver.Chrome(executable_path ='/Applications/chromedriver')
WebDriverWait(driver,100,1)
driver.get(URL)

subhtml = driver.page_source
soup = BeautifulSoup(subhtml, "html.parser")
df = pd.DataFrame()

while True:
    
    for i in soup.find_all(class_='col-12-3 col-sm-12-6 list-item'):
        
        #go inside product page
        nextlink = domain + i.find(class_='goods-title')['href']
        print(nextlink)
        driver.get(nextlink)
        temp = driver.page_source
        soup = BeautifulSoup(temp, "html.parser")

        
        # extract product name        
        try:
            product_title = soup.find(class_='product-grid-line product-title').text
            print(product_title)
        except:
            product_title = np.nan
            print('title error')
            

        # extract product price
        try:
            product_price = soup.find(class_='product-price').text.strip()
            print(product_price)
        except:
            product_price = np.nan
              
        
        # extract product image
        try:
            product_image = soup.select('img')[32]['lazysrc']
            print('http:' + product_image)
        except:
            product_image = np.nan
    

        # product url
        try:
            product_url = domain + i.find('a')['href']
            # print(product_url)
        except:
            product_url = np.nan

        
        df = df.append({'product_title' : product_title,
                        'product_price' : product_price,
                        'product_image' : product_image,
                        'product_url' : product_url}, ignore_index = True)

        
    #going back to main page after looping    
    temp = driver.get(URL) 
    subhtml = driver.page_source
    soup = BeautifulSoup(subhtml, "html.parser")


    # #going to the next page
    # temp2 = soup.find(class_='a-last').a['href']
    # URL = domain + temp2
    # driver.get(URL)
    # subhtml = driver.page_source
    # soup = BeautifulSoup(subhtml, "html.parser")

# %%
 # Smooth Scorlling
total_height = int(driver.execute_script("return document.body.scrollHeight"))
for i in range(1, total_height, 5):
    driver.execute_script("window.scrollTo(0, {});".format(i))

# %%
df_men_shorts['product_price'].str.replace('From £','')
# Out:
# 0     £34.95
# 1     £29.95
# 2     £38.00
# 3     £34.95
# 4     £33.00
#        ...
# 80    £18.90
# 81    £23.05
# 82    £12.00
# 83     50.85
# 84    £18.20
# Name: product_price, Length: 85, dtype: object

# %%
df_men_longsleeve['product_price'].str.extract(r'(\d+....)')
#re.findall(r'\d+', test_string)
# Out:
#         0
# 0   31.45
# 1   41.95
# 2   94.40
# 3   49.45
# 4   35.00
# 5   38.50
# 6   38.65
# 7   38.65
# 8   38.65
# 9   38.65
# 10  34.15
# 11  94.40
# 12  49.45
# 13  36.50
# 14  38.65
# 15  49.45
# 16  58.50
# 17  58.45
# 18  36.55
# 19  30.35
# 20  34.15
# 21  36.50
# 22  26.55
# 23  31.45
# 24  49.45
# 25  30.05
# 26  31.50
# 27  38.45
# 28  46.75
# 29  81.90
# 30  39.95
# 31  32.95
# 32  38.20
# 33  44.95
# 34  32.00
# 35  51.95
# 36  31.45
# 37  30.55
# 38  34.20

# %%
#df_men_shorts['price_hkd'] = 
df_men_longsleeve['price_hkd']=round(df_men_longsleeve['product_price'].str.extract(r'(\d+....)')[0].apply(lambda x: float(x))*10.4154844,2)
#df_men_shorts
#round(.2)
df_men_shorts['price_hkd'][16]
# Out:
# 468.18

# %%
df_men_longsleeve
# Out:
#                                         product_image product_price  \
# 0   http://images.asos-media.com/products/adidas-b...        £31.45
# 1   http://images.asos-media.com/products/adidas-a...        £41.95
# 2   http://images.asos-media.com/groups/adidas-ori...   From £94.40
# 3   http://images.asos-media.com/products/adidas-o...        £49.45
# 4   http://images.asos-media.com/products/adidas-s...        £35.00
# 5   http://images.asos-media.com/products/adidas-t...        £38.50
# 6   http://images.asos-media.com/products/adidas-o...        £38.65
# 7   http://images.asos-media.com/products/adidas-o...        £38.65
# 8   http://images.asos-media.com/products/adidas-o...        £38.65
# 9   http://images.asos-media.com/products/adidas-o...        £38.65
# 10  http://images.asos-media.com/products/adidas-o...        £34.15
# 11  http://images.asos-media.com/groups/adidas-ori...   From £94.40
# 12  http://images.asos-media.com/products/adidas-o...        £49.45
# ...

# %%
df_men_shortsleeve=pd.read_csv('men_shortsleeve.csv')
df_men_shortsleeve
# Out:
#                                          product_image product_price  \
# 0    http://images.asos-media.com/products/adidas-t...        £34.95
# 1    http://images.asos-media.com/products/adidas-t...        £28.00
# 2    http://images.asos-media.com/products/adidas-t...        £27.95
# 3    http://images.asos-media.com/products/adidas-t...        £22.00
# 4    http://images.asos-media.com/products/adidas-8...        £16.00
# ..                                                 ...           ...
# 206  http://images.asos-media.com/products/adidas-t...        £15.60
# 207  http://images.asos-media.com/products/adidas-o...        £16.80
# 208  http://images.asos-media.com/products/adidas-z...        £13.50
# 209  http://images.asos-media.com/products/adidas-t...         £8.00
# 210  http://images.asos-media.com/products/adidas-o...        £19.20
#
#                                          product_title  \
# 0    adidas Training t-shirt with high chest logo i...
# ...

# %%
#df_men_shorts['price_hkd'] = 
df_men_shortsleeve['price_hkd']=round(df_men_shortsleeve['product_price'].str.extract(r'(\d+....)')[0].apply(lambda x: float(x))*10.4154844,2)
#df_men_shorts
#round(.2)
df_men_shortsleeve
# Out:
#                                          product_image product_price  \
# 0    http://images.asos-media.com/products/adidas-t...        £34.95
# 1    http://images.asos-media.com/products/adidas-t...        £28.00
# 2    http://images.asos-media.com/products/adidas-t...        £27.95
# 3    http://images.asos-media.com/products/adidas-t...        £22.00
# 4    http://images.asos-media.com/products/adidas-8...        £16.00
# ..                                                 ...           ...
# 206  http://images.asos-media.com/products/adidas-t...        £15.60
# 207  http://images.asos-media.com/products/adidas-o...        £16.80
# 208  http://images.asos-media.com/products/adidas-z...        £13.50
# 209  http://images.asos-media.com/products/adidas-t...         £8.00
# 210  http://images.asos-media.com/products/adidas-o...        £19.20
#
#                                          product_title  \
# 0    adidas Training t-shirt with high chest logo i...
# ...

# %%
df_men_shortsleeve.to_csv('men_shortsleeve2.csv')
