# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import regex as re
import numpy as np
import requests
import string
import time

# %%
df = pd.read_csv('data/Amazon_adidas_shirts3A.csv', index_col=0)

# %%
df
# Out:
#       Brand                              Category  Discounted Price  \
# 0    adidas                    Active                        241.18
# 2    adidas                    Active                        341.93
# 3    adidas                    Shirts                        110.86
# 5    adidas                    Active                        112.03
# 7    adidas                    Shirts                        167.19
# ..      ...                                   ...               ...
# 426  adidas                   Shirts                         465.48
# 427  adidas                   Shirts                         465.48
# 428  adidas                   Shirts                         465.48
# 429  adidas                   Shirts                         465.48
# 430  adidas                   Shirts                         465.48
#
#                                                 Images  Original Price  \
# 0    https://images-na.ssl-images-amazon.com/images...          241.18
# ...

# %%
df_ShortTees = df[df['Product Name'].str.contains('T')]
df_ShortTees
# Out:
#       Brand                              Category  Discounted Price  \
# 0    adidas                    Active                        241.18
# 3    adidas                    Shirts                        110.86
# 5    adidas                    Active                        112.03
# 14   adidas                    Active                        190.30
# 15   adidas                  Clothing                        272.22
# ..      ...                                   ...               ...
# 426  adidas                   Shirts                         465.48
# 427  adidas                   Shirts                         465.48
# 428  adidas                   Shirts                         465.48
# 429  adidas                   Shirts                         465.48
# 430  adidas                   Shirts                         465.48
#
#                                                 Images  Original Price  \
# 0    https://images-na.ssl-images-amazon.com/images...          241.18
# ...

# %%
df = df.drop(index=[ 26, 230, 232, 235, 240, 250, 262, 291, 297, 308, 311, 313, 317, 324, 340, 362, 363, 364, 365, 367, 368, 369, 378, 379, 380, 389, 391, 392, 402, 404, 406, 408, 409, 415, 418, 419, 428, 429, 430],  axis=0)
df
# Out:
#       Brand                                Category  Discounted Price  \
# 2    adidas                      Active                        341.93
# 5    adidas                      Active                        112.03
# 7    adidas                      Shirts                        167.19
# 8    adidas                      Active                        339.83
# 9    adidas                                     NaN            465.32
# ..      ...                                     ...               ...
# 423  adidas                   T-Shirts                         100.75
# 424  adidas                    Jerseys                         700.20
# 425  adidas                     Shirts                         465.48
# 426  adidas                     Shirts                         465.48
# 427  adidas                     Shirts                         465.48
#
#                                                 Images  Original Price  \
# ...

# %%
df_ShortTees.to_csv('Amazon_adidas_ShortTees3A_final1.csv', index = True)
