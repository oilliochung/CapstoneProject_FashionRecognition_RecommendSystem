# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import regex as re
import numpy as np
import requests
import string
import time

# %%
df = pd.read_csv('data/Amazon_adidas_active3Aa.csv', index_col=0)

# %%
df
# Out:
#                  Brand                              Category  \
# 0               adidas                    Active
# 1     adidas Originals                    Active
# 2               adidas                    Active
# 3               adidas                    Active
# 4               adidas                    Active
# ...                ...                                   ...
# 1540            adidas                  Clothing
# 1541            adidas                    Active
# 1542            adidas                  Clothing
# 1544            adidas                    Active
# 1545            adidas                  Clothing
#
#       Discounted Price                                             Images  \
# 0               143.07  https://images-na.ssl-images-amazon.com/images...
# 1               387.21  https://images-na.ssl-images-amazon.com/images...
# 2               194.11  https://images-na.ssl-images-amazon.com/images...
# ...

# %%
df_pant = df[df['Product Name'].str.contains('Pant')]
df_pant
# Out:
#                  Brand                              Category  \
# 9               adidas                       Men
# 22              adidas                       Men
# 23              adidas                       Men
# 24              adidas                    Active
# 33    adidas Originals                       Men
# ...                ...                                   ...
# 1511            adidas                  Clothing
# 1517            adidas                  Clothing
# 1532            adidas                   Active
# 1537            adidas                    Active
# 1539            adidas                    Active
#
#       Discounted Price                                             Images  \
# 9               295.56  https://images-na.ssl-images-amazon.com/images...
# 22              232.16  https://images-na.ssl-images-amazon.com/images...
# 23              536.82  https://images-na.ssl-images-amazon.com/images...
# ...

# %%
df_pant = df_pant.drop(index=[33, 65, 67, 89, 95, 99, 114, 123, 129, 131, 229, 256, 270, 283, 306, 342, 369, 418, 431, 446, 456, 494, 513, 614, 752, 772, 773, 840, 855, 862, 869, 1154, 1169, 1201],  axis=0)
df_pant
# Out:
#                  Brand                              Category  \
# 9               adidas                       Men
# 22              adidas                       Men
# 23              adidas                       Men
# 24              adidas                    Active
# 38    adidas Originals                    Active
# ...                ...                                   ...
# 1511            adidas                  Clothing
# 1517            adidas                  Clothing
# 1532            adidas                   Active
# 1537            adidas                    Active
# 1539            adidas                    Active
#
#       Discounted Price                                             Images  \
# 9               295.56  https://images-na.ssl-images-amazon.com/images...
# 22              232.16  https://images-na.ssl-images-amazon.com/images...
# 23              536.82  https://images-na.ssl-images-amazon.com/images...
# ...

# %%
df_pant.to_csv('Amazon_adidas_longpants3A_final1.csv', index = True)
